# %%
# This is a Python 3 environment

# Base level imports for data science work

import numpy as np 
import pandas as pd
import re,string,unicodedata
import os
from os import path

# Visualization Libs
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# NLP Libs
import nltk
from sklearn.preprocessing import LabelBinarizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from bs4 import BeautifulSoup
from keras.preprocessing import text, sequence
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC

# Additional Libs
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from string import punctuation
from nltk import pos_tag
from nltk.corpus import wordnet

# Deep Learning Libs
import keras
from keras.models import Sequential
from keras.layers import Dense,Embedding,LSTM,Dropout
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# Import our data

true = pd.read_csv("True.csv")
fake = pd.read_csv("Fake.csv")

# %%
# Let's explore the data at a base level

true.sample(20)
# Out:
#                                                    title  \
# 5260   Democrats must overhaul party, attack big busi...
# 19845  Japan's PM Abe considers snap election as earl...
# 14765  Fifteen bullet-ridden kidnap victims found in ...
# 15583  Hungarians take walking tour to overcome fears...
# 16009  Those who boycott Syrian congress may be sidel...
# 9974   U.S. presidential rivals Clinton, Sanders tied...
# 12776  IMF's Lagarde tells Ukraine president to speed...
# 20940  'Suicidal' Danish submarine owner says journal...
# 182    U.S. House and Senate leaders reach agreement ...
# 3723   House panel seeks FBI, Department of Justice d...
# 10604  Unlocking iPhone would leave millions exposed,...
# 19404  Mexico politicians fear flunking quake test be...
# 8400   Clinton leads Trump by 12 points in Reuters/Ip...
# 20837  Lesotho detains army major over killing of mil...
# 18608  Police break into voting station where Catalan...
# 4044   Trump's plan to slash business taxes seen as '...
# 1540   U.S. plans to admit maximum 45,000 refugees in...
# 15854  Factbox: Gavin Williamson - Britain's new defe...
# 11350  U.S. sanctions two North Korean officials over...
# 2393   Scaramucci drama has no bearing on pending Sky...
#
#                                                     text       subject  \
# 5260   WASHINGTON (Reuters) - Former U.S. Democratic ...  politicsNews
# 19845  TOKYO (Reuters) - Japanese Prime Minister Shin...     worldnews
# 14765  QUETTA, Pakistan (Reuters) - Pakistani police ...     worldnews
# 15583  BUDAPEST (Reuters) - A walking tour to learn a...     worldnews
# 16009  ASTANA (Reuters) - Syrian groups who choose to...     worldnews
# 9974    NEW YORK (Reuters) - The top contenders in bo...  politicsNews
# 12776  KIEV (Reuters) - The head of the International...     worldnews
# 20940  COPENHAGEN (Reuters) - Swedish journalist Kim ...     worldnews
# 182    WASHINGTON (Reuters) - Republican leaders in t...  politicsNews
# 3723   WASHINGTON (Reuters) - The House Intelligence ...  politicsNews
# 10604  WASHINGTON (Reuters) - Unlocking an iPhone use...  politicsNews
# 19404   (This version of September 20 s story correct...     worldnews
# 8400   NEW YORK (Reuters) - Democratic presidential n...  politicsNews
# 20837  MASERU (Reuters) - Lesotho has detained a seni...     worldnews
# 18608  SANT JULIA DE RAMIS, Spain (Reuters) - Spanish...     worldnews
# 4044   WASHINGTON (Reuters) - President Donald Trump ...  politicsNews
# 1540   WASHINGTON (Reuters) - The Trump administratio...  politicsNews
# 15854  LONDON (Reuters) - Gavin Williamson was appoin...     worldnews
# 11350  WASHINGTON (Reuters) - The United States on Tu...     worldnews
# 2393   NEW YORK (Reuters) - Anthony Scaramucci’s swif...  politicsNews
#
#                       date
# 5260    February 26, 2017
# 19845  September 17, 2017
# 14765   November 15, 2017
# 15583    November 6, 2017
# 16009    October 31, 2017
# 9974       April 12, 2016
# 12776    December 8, 2017
# 20940   September 5, 2017
# 182     December 13, 2017
# 3723         May 18, 2017
# 10604   February 29, 2016
# 19404  September 21, 2017
# 12169        Dec 11, 2016
# 6474          May 8, 2016
# 12910        Sep 26, 2016

# %%
true.shape,fake.shape
# Out:
# ((21417, 4), (23481, 4))

# %%
# These dataframes do not currently have a category for whether they are true or fake.
# Let's create those before we combine the datasets

true['category'] = 1
fake['category'] = 0

# %%
# Now we'll merge the two datasets into a single dataframe

df = pd.concat([true,fake])

# %%
df.sample(10)
# Out:
#                                                    title  \
# 8143    Anti-Obama ESPN Host Cuts Off Singer As He Be...
# 3495    WATCH: Trump Is Now Criticizing Time’s ‘Perso...
# 1292   FCC head silent on Trump comment about pulling...
# 14782  Divided Srebrenica awaits Mladic verdict 22 ye...
# 15396  “DEAD BROKE” HILLARY HITS A SWANKY SALON WITH ...
# 17209  Israel: No peace talks with Palestinian govern...
# 19027  TUCKER CARLSON Defends Trump’s Wiretapping All...
# 12846  Al Qaeda condemns Trump's Jerusalem move, call...
# 19850  Varadkar bounce gives Ireland's Fine Gael eigh...
# 23311                    SUNDAY SCREENING: PSYWAR (2010)
#
#                                                     text       subject  \
# 8143   ESPN has a bit of a conservative bias problem....          News
# 3495   Even though former reality show star turned pr...          News
# 1292   WASHINGTON (Reuters) - A suggestion by Preside...  politicsNews
# 14782  SREBRENICA, Bosnia (Reuters) - Almir Salihovic...     worldnews
# 15396  Wait! I thought she was  dead broke  and just ...      politics
# 17209  JERUSALEM (Reuters) - Israel said on Tuesday i...     worldnews
# 19027  FOX and Friends spoke with Tucker Carlson this...     left-news
# 12846  DUBAI (Reuters) - Islamist militant group Al Q...     worldnews
# 19850  DUBLIN (Reuters) - Ireland s ruling Fine Gael ...     worldnews
# 23311  21st Century Wire says Our weekly documentary ...   Middle-east
#
#                       date  category
# 8143     February 13, 2016         0
# 3495      December 9, 2016         0
# 1292     October 12, 2017          1
# 14782   November 15, 2017          1
# 15396         Jul 29, 2015         0
# 17209    October 17, 2017          1
# 19027          Mar 6, 2017         0
# 12846    December 7, 2017          1
# 19850  September 17, 2017          1
# 23311         July 3, 2016         0

# %%
plt.figure(figsize=(16,9))

sns.countplot(df.category)
plt.title('Total Fake and Real News Articles', fontsize=24)
plt.ylabel('Total', fontsize=16)
plt.xlabel('')
plt.xticks([0, 1], ['Fake', 'Real'], fontsize=16)

plt.show()

# %%
df.isna().sum()
# Out:
# title       0
# text        0
# subject     0
# date        0
# category    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 0 to 23480
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     44898 non-null  object
#  1   text      44898 non-null  object
#  2   subject   44898 non-null  object
#  3   date      44898 non-null  object
#  4   category  44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 3.3+ MB

# %%
# From all of the above exploration we can see we have a fairly balanced dataset. There are also no null values
# We have a total of 44,898 observations to work with moving forward.

# %%
# One last thing I'm interested in looking at at this point

df.subject.value_counts()
# Out:
# politicsNews       11272
# worldnews          10145
# News                9050
# politics            6841
# left-news           4459
# Government News     1570
# US_News              783
# Middle-east          778
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(16,9))
sns.countplot(x='subject', data=df)

plt.title('Total Number of Articles Per Subject', fontsize=24)
plt.ylabel('Total', fontsize=16)
plt.xlabel('')
plt.xticks(fontsize=12)

plt.show()

# %%
# Hmmmm... Interesting.

# %%
plt.figure(figsize=(16,9))
sns.countplot(x='subject', hue='category', data=df)

plt.title('Article Subjects By Type', fontsize=24)
plt.ylabel('Total', fontsize=16)
plt.xlabel('')
plt.xticks(fontsize=12)
plt.legend(['Fake', 'Real'])

plt.show()

# %%
# Well, now that is interesting. It's clear that if we include the 'Subject' column in our further exploration
# and analysis it will have a significant impact on our results. So, we'll need to drop that column.

# %%
df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  category
# 0  December 31, 2017          1
# 1  December 29, 2017          1
# 2  December 31, 2017          1
# 3  December 30, 2017          1
# 4  December 29, 2017          1

# %%
# Now we'll create the Corpus that will be used in our NLP model

# This will create a single column with all the relevant text

df['text'] = df['title'] + " " + df['text']

# This will delete all the other columns we do not need for the rest of the work.
del df['title'] # added to our text corpus
del df['subject'] # we determined it would affect our results
del df['date'] # this might be an interesting item to keep in a future analysis that spans more time, but we will delete it for now.

# %%
# Now we need to clean up the corpus. We'll do this by removing stop words, URLs, brackets, etc.

# %%
stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

# Removing the square brackets
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)

# Removing URL's
def remove_between_square_brackets(text):
    return re.sub(r'http\S+', '', text)

# Removing the stopwords from text
def remove_stopwords(text):
    final_text = []
    for i in text.split():
        if i.strip().lower() not in stop:
            final_text.append(i.strip())
    return " ".join(final_text)

# Final function to clean the text
def clean_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    text = remove_stopwords(text)
    return text
#Apply function on review column
df['text']=df['text'].apply(clean_text)

# %%
df.head()
# Out:
#                                                 text  category
# 0  U.S. budget fight looms, Republicans flip fisc...         1
# 1  U.S. military accept transgender recruits Mond...         1
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...         1
# 3  FBI Russia probe helped Australian diplomat ti...         1
# 4  Trump wants Postal Service charge 'much more' ...         1

# %%
# Now we'll make a few crowd favorites: Word Clouds. We'll make two version. The first will be a typical set,
# then we'll dress them up a bit.

# %%
plt.figure(figsize = (20,20)) # Text from the real news articles
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800 , stopwords = STOPWORDS).generate(" ".join(df[df.category == 1].text))
plt.imshow(wc , interpolation = 'bilinear')
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (20,20)) # Text from the fake news articles
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800 , stopwords = STOPWORDS).generate(" ".join(df[df.category == 0].text))
plt.imshow(wc , interpolation = 'bilinear')

plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Those word clouds look ok. And they can definitely be altered by a bit of color. Here's a custom look.

# %%
plt.figure(figsize = (20,20))
def clean(text: str) -> list:
    'A simple function to cleanup text data'
    
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english')
    text = (text.encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
    words = re.sub(r'[^\w\s]', '', text).split() # tokenization
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

corpus = clean(' '.join(df[df.category == 1].text))

def listToString(s):  
    
    # initialize an empty string 
    str1 = " " 
    
    # return string   
    return (str1.join(s)) 

corpus_str = listToString(corpus)

d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# read the mask / color image taken from
coloring = np.array(Image.open(path.join(d, "real_news.jpg")))
stopwords = set(STOPWORDS)

wc = WordCloud(background_color="white", max_words = 2000 , width = 1600 , height = 800, mask=coloring,
               stopwords=stopwords, max_font_size=80, random_state=42)

# generate word cloud
wc.generate(corpus_str)

# create coloring from image
image_colors = ImageColorGenerator(coloring)

plt.imshow(wc, interpolation='bilinear')
plt.axis("off")

# # This bit of code is used to create a high quality exported image
# fig1 = plt.gcf()
# plt.show()
# plt.draw()
# fig1.savefig("real_news_nlp_word_cloud.png", bbox_inches='tight', dpi=600)
# Out:
# (-0.5, 3029.5, 1090.5, -0.5)

# %%
plt.figure(figsize = (20,20))
def clean(text: str) -> list:
    'A simple function to cleanup text data'
    
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english')
    text = (text.encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
    words = re.sub(r'[^\w\s]', '', text).split() # tokenization
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

corpus = clean(' '.join(df[df.category == 0].text))

def listToString(s):  
    
    # initialize an empty string 
    str1 = " " 
    
    # return string   
    return (str1.join(s)) 

corpus_str = listToString(corpus)

d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# read the mask / color image taken from
coloring = np.array(Image.open(path.join(d, "fake_news.jpg")))
stopwords = set(STOPWORDS)

wc = WordCloud(background_color="white", max_words=2000, mask=coloring,
               stopwords=stopwords, max_font_size=80, random_state=42)

# generate word cloud
wc.generate(corpus_str)

# create coloring from image
image_colors = ImageColorGenerator(coloring)

plt.imshow(wc, interpolation='bilinear')
plt.axis("off")

# # This bit of code is used to create a high quality exported image
# fig1 = plt.gcf()
# plt.show()
# plt.draw()
# fig1.savefig("fake_news_nlp_word_cloud.png", bbox_inches='tight', dpi=600)
# Out:
# (-0.5, 3029.5, 1090.5, -0.5)

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(16,9))
text_len=df[df['category']==1]['text'].str.len()
ax1.hist(text_len,color='tab:orange')
ax1.set_title('Real News', fontsize=14)
text_len=df[df['category']==0]['text'].str.len()
ax2.hist(text_len,color='tab:blue')
ax2.set_title('Fake News', fontsize=14)
fig.suptitle('Characters per article', fontsize=24)

plt.show()

# %%
# There seem to be differences in the characters per article between the two categories. It looks like 
# 2500 or less characters in text is the most common in real news category, while around 5000 or less
# characters in text are most common in fake news category.

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(16,9))
text_len=df[df['category']==1]['text'].str.split().map(lambda x: len(x))
ax1.hist(text_len,color='tab:orange')
ax1.set_title('Real News', fontsize=14)
text_len=df[df['category']==0]['text'].str.split().map(lambda x: len(x))
ax2.hist(text_len,color='tab:blue')
ax2.set_title('Fake News', fontsize=14)
fig.suptitle('Words per article', fontsize=24)

# plt.title('Article Subjects By Type')
# plt.ylabel('Total', fontsize=16)
# plt.xlabel('')
# plt.xlim(fontsize=12)
# plt.legend(['Fake', 'Real'])
plt.show()

# %%
# Now that we've done a bit of data exploration, let's get into modeling

# %%
# First up, we need to Train Test Split the data

X = df.text
y = df.category

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8,stratify=y, random_state=19)

# %%
X = df.text
y = df.category

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8,stratify=y, random_state=19)

# Create of Count Vectorize object
cv=CountVectorizer(min_df=0,max_df=1,binary=False,ngram_range=(1,3))

# Transform the train dataset
cv_train=cv.fit_transform(X_train)

# Transform the test dataset
cv_test=cv.transform(X_test)

print('Bag of words Train:',cv_train.shape)
print('Bag of words Test:',cv_test.shape)
# Out:
# Bag of words Train: (35918, 7356970)
# Bag of words Test: (8980, 7356970)

# %%
# Create the TF-IDF object
tfidf=TfidfVectorizer(min_df=0,max_df=1,use_idf=True,ngram_range=(1,3))

# Transform the train dataset
tfidf_train=tfidf.fit_transform(X_train)

# Transform the test dataset
tfidf_test=tfidf.transform(X_test)

print('TF-IDF Train:',tfidf_train.shape)
print('TF-IDF Test:',tfidf_test.shape)
# Out:
# TF-IDF Train: (35918, 7356970)
# TF-IDF Test: (8980, 7356970)

# %%
# Create our model object
mnb = MultinomialNB()

# Fit the model to the Bag of words CountVectorizor
mnb_cv = mnb.fit(cv_train, y_train)

# Fit the model to the TF-IDF features
mnb_tfidf = mnb.fit(tfidf_train, y_train)

# %%
# Predicting the model for bag of words
mnb_cv_predict=mnb.predict(cv_test)

# Predicting the model for tf-idf features
mnb_tfidf_predict=mnb.predict(tfidf_test)

# %%
# Check the accuracy score for bag of words
mnb_cv_score=accuracy_score(y_test, mnb_cv_predict)
print("Naive Bayes Bag of words accuracy score:", mnb_cv_score)

# Check the accuracy score for tfidf features
mnb_tfidf_score=accuracy_score(y_test,mnb_tfidf_predict)
print("Naive Bayes TF-IDF accuracy score:", mnb_tfidf_score)
# Out:
# Naive Bayes Bag of words accuracy score: 0.9425389755011135
# Naive Bayes TF-IDF accuracy score: 0.9174832962138084

# %%
mnb_cv_report = classification_report(y_test, mnb_cv_predict, target_names = ['0','1'])
print(mnb_cv_report)
mnb_tfidf_report = classification_report(y_test, mnb_tfidf_predict, target_names = ['0','1'])
print(mnb_tfidf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95      4696
#            1       0.95      0.93      0.94      4284
#
#     accuracy                           0.94      8980
#    macro avg       0.94      0.94      0.94      8980
# weighted avg       0.94      0.94      0.94      8980
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.93      4696
#            1       0.98      0.85      0.91      4284
#
#     accuracy                           0.92      8980
#    macro avg       0.93      0.91      0.92      8980
# weighted avg       0.92      0.92      0.92      8980

# %%
# At the end of some quick EDA and NLP modeling, we're left with a high level understanding of the two datasets,
# some charts and word clouds for a data product, and a model that currently has 94% accuracy with Bag of Words
# and 92% with TF-IDF.
